# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Weather URL
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#Columns (Keys)
is_fetch_ok = "Is_Fetch_Ok"
city_id     = "City_ID"
city        = "City"
cloudiness  = "Cloudiness"
country     = "Country"
date        = "Date"
humidity    = "Humidity"
lat         = "Lat"
lng         = "Lng"
max_temp    = "Max Temp"
wind_speed  = "Wind Speed"

# List for holding lat_lngs and cities
lat_lngs     = []

#Keeping track of processed cities
cities       = []

#Stores all weather-relevant data for a given set of coordinates
weather_container = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    
    city_name    = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country_code = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to 'cities'
    if city_name not in cities:
        
        weather_hash  = {
                             is_fetch_ok : False,
                             city_id     : None, 
                             city        : city_name, 
                             cloudiness  : None, 
                             country     : country_code.upper(),
                             date        : None,
                             humidity    : None,
                             lat         : lat_lng[0],
                             lng         : lat_lng[1],
                             max_temp    : None,
                             wind_speed  : None
                        }        
        
        weather_container.append(weather_hash)
        cities.append(city_name)
        
# Print the city count to confirm (sufficient) count
print(f"The pseudo-random number of unique cities in this unit of execution is {len(cities)}")
# Out:
# The pseudo-random number of unique cities in this unit of execution is 611

# %%
weather_container
# Out:
# [{'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'busselton',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -54.308497393344936,
#   'Lng': 103.36303177299442,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tual',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -6.354505434317517,
#   'Lng': 134.375990726091,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'narsaq',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 74.7693092340873,
#   'Lng': -66.14316483438061,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'illoqqortoormiut',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 89.82551594285499,
#   'Lng': -25.467177955904788,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'taolanaro',
#   'Cloudiness': None,
#   'Country': 'MG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -29.002308341153743,
#   'Lng': 48.85446631377249,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ushuaia',
#   'Cloudiness': None,
#   'Country': 'AR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -82.5860786613285,
#   'Lng': -82.62532560080149,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'fruitvale',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.88614616833286,
#   'Lng': -117.46510050137582,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sitka',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 50.784400423239134,
#   'Lng': -141.06328673232295,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saskylakh',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 80.55365348074147,
#   'Lng': 109.91988211942271,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'barrow',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 76.45924697282854,
#   'Lng': -160.71532582719277,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ishigaki',
#   'Cloudiness': None,
#   'Country': 'JP',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 21.02767779299012,
#   'Lng': 126.02558528082062,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chokurdakh',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 72.75442368845182,
#   'Lng': 145.77981380389178,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'medianeira',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -25.01994643722486,
#   'Lng': -54.27100690635028,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'rikitea',
#   'Cloudiness': None,
#   'Country': 'PF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -46.104406871103805,
#   'Lng': -108.78448168752111,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'yablochnyy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 47.13324648363292,
#   'Lng': 142.09536586136215,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tsihombe',
#   'Cloudiness': None,
#   'Country': 'MG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -43.259430738937205,
#   'Lng': 46.715454130661726,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'meadow lake',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 56.0482897439733,
#   'Lng': -108.78269844304074,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'east london',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -33.30307339014929,
#   'Lng': 27.792752040314355,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'yellowknife',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 68.58097846710317,
#   'Lng': -112.48393482447145,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nepomuceno',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -21.350504484606944,
#   'Lng': -45.30305616140538,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'arraial do cabo',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -31.496134061951302,
#   'Lng': -35.332038091002005,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'jamestown',
#   'Cloudiness': None,
#   'Country': 'SH',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -32.923331844667224,
#   'Lng': -5.543693372772822,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bonthe',
#   'Cloudiness': None,
#   'Country': 'SL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 3.347139983066782,
#   'Lng': -17.607150593044366,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'port macquarie',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -33.243161428183676,
#   'Lng': 161.11444192390712,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'poum',
#   'Cloudiness': None,
#   'Country': 'NC',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -22.51140263100784,
#   'Lng': 159.18897065947834,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hobart',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -57.320126366339906,
#   'Lng': 150.46199058844184,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tinskoy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 55.22522124105083,
#   'Lng': 96.7962500202139,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'skalistyy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 73.93648560652701,
#   'Lng': 34.82169372284659,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'agadez',
#   'Cloudiness': None,
#   'Country': 'NE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 18.06931503300393,
#   'Lng': 8.874728085937875,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'port blair',
#   'Cloudiness': None,
#   'Country': 'IN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 11.67679253023121,
#   'Lng': 86.766709680762,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'honiara',
#   'Cloudiness': None,
#   'Country': 'SB',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -14.95403425154747,
#   'Lng': 157.34802484818005,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'port elizabeth',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -85.23744397746182,
#   'Lng': 31.58958186551851,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mys shmidta',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 80.84691165159131,
#   'Lng': -176.50957126717245,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'la asuncion',
#   'Cloudiness': None,
#   'Country': 'VE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 13.16012833661577,
#   'Lng': -64.75705347784913,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'olavarria',
#   'Cloudiness': None,
#   'Country': 'AR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -36.53480013192265,
#   'Lng': -61.18931208731533,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ribeira grande',
#   'Cloudiness': None,
#   'Country': 'PT',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 29.423613908690854,
#   'Lng': -40.11770307230509,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'iqaluit',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 62.39484603307744,
#   'Lng': -77.42830303804448,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'albany',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -44.97265127646667,
#   'Lng': 114.09894095875705,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'cabo san lucas',
#   'Cloudiness': None,
#   'Country': 'MX',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 11.68467415297323,
#   'Lng': -118.48862710200981,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'butaritari',
#   'Cloudiness': None,
#   'Country': 'KI',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 19.9463575888567,
#   'Lng': 167.07253540489427,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'cape town',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -67.16318172836105,
#   'Lng': -6.636126315391664,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'punta arenas',
#   'Cloudiness': None,
#   'Country': 'CL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -67.09747407904781,
#   'Lng': -103.4406312215328,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bousso',
#   'Cloudiness': None,
#   'Country': 'TD',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 10.838378253308235,
#   'Lng': 16.81055373751485,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mentok',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -2.6880680393781518,
#   'Lng': 106.2966773852038,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'gannan',
#   'Cloudiness': None,
#   'Country': 'CN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 47.57837013668038,
#   'Lng': 123.59818132289053,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kununurra',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -16.291449034454388,
#   'Lng': 126.02357433507973,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'porosozero',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 63.13610803245868,
#   'Lng': 32.564898996171934,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'adrar',
#   'Cloudiness': None,
#   'Country': 'DZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 30.060147000728776,
#   'Lng': -1.8806996998656018,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hithadhoo',
#   'Cloudiness': None,
#   'Country': 'MV',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -7.321948115660916,
#   'Lng': 83.48823712383,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kodiak',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 42.780040911253934,
#   'Lng': -148.44956455086634,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'umm lajj',
#   'Cloudiness': None,
#   'Country': 'SA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 26.480876122714136,
#   'Lng': 36.531750308141255,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'grand gaube',
#   'Cloudiness': None,
#   'Country': 'MU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -14.915077497952339,
#   'Lng': 63.43521357992938,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'balikpapan',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -1.9566044250720012,
#   'Lng': 117.64546855656238,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'devonport',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -40.16339862107684,
#   'Lng': 146.72506776378253,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'port alfred',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -67.98600672346998,
#   'Lng': 42.923871503524765,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bosaso',
#   'Cloudiness': None,
#   'Country': 'SO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 10.748756341633268,
#   'Lng': 47.81218314285675,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'preobrazheniye',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 42.10794525164923,
#   'Lng': 133.72643869116013,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mackenzie',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 54.84825503183217,
#   'Lng': -122.00135273887796,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ensley',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 30.991256228173725,
#   'Lng': -87.42196139756777,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'murray bridge',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -34.12069029082019,
#   'Lng': 140.03982168353235,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'fortuna',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 39.95124919146329,
#   'Lng': -133.38886907076284,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'anloga',
#   'Cloudiness': None,
#   'Country': 'GH',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 2.6363084283582197,
#   'Lng': 1.7254906716602534,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mount gambier',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -45.48020880105935,
#   'Lng': 134.99025418816603,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bilibino',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 68.99497370916632,
#   'Lng': 164.47411677127826,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saleaula',
#   'Cloudiness': None,
#   'Country': 'WS',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.790219641858684,
#   'Lng': -165.90300701530387,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'atuona',
#   'Cloudiness': None,
#   'Country': 'PF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -10.805672212194409,
#   'Lng': -135.0208494924871,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saint-philippe',
#   'Cloudiness': None,
#   'Country': 'RE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -69.19100936330024,
#   'Lng': 71.3976309781086,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'abu samrah',
#   'Cloudiness': None,
#   'Country': 'QA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 23.73825293441503,
#   'Lng': 52.15201433304321,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'yar-sale',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 68.77325321015834,
#   'Lng': 70.50725936489471,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'caloundra',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -26.765307027507582,
#   'Lng': 154.4642358778912,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'balotra',
#   'Cloudiness': None,
#   'Country': 'IN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 25.57576025711117,
#   'Lng': 72.05351924548637,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'aklavik',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 67.04607167415355,
#   'Lng': -134.83829122796743,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'shihezi',
#   'Cloudiness': None,
#   'Country': 'CN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 43.85313155942515,
#   'Lng': 85.53783153107247,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'port lincoln',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -34.67279050543927,
#   'Lng': 134.34792819475842,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kovdor',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 67.53775261615542,
#   'Lng': 30.666705999063737,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'banjar',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -7.405007696623187,
#   'Lng': 107.3264984294471,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'jahrom',
#   'Cloudiness': None,
#   'Country': 'IR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 28.517437516190526,
#   'Lng': 52.47233196066847,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'zhigansk',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 68.0080851161677,
#   'Lng': 125.88827130997174,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'avarua',
#   'Cloudiness': None,
#   'Country': 'CK',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -17.75110379523383,
#   'Lng': -159.2245770935976,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'maarianhamina',
#   'Cloudiness': None,
#   'Country': 'FI',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 60.42036154463048,
#   'Lng': 20.438851340735027,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vallenar',
#   'Cloudiness': None,
#   'Country': 'CL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -27.098857532728132,
#   'Lng': -75.64525045768096,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'laguna',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -31.834700205689565,
#   'Lng': -42.36508274977538,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ranong',
#   'Cloudiness': None,
#   'Country': 'TH',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 9.568204816687839,
#   'Lng': 96.22237791147899,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bluff',
#   'Cloudiness': None,
#   'Country': 'NZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -88.85761281498637,
#   'Lng': 175.7665898130046,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'katobu',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -6.5811925920480405,
#   'Lng': 123.3588640343279,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'carnarvon',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -22.971449441533082,
#   'Lng': 102.72147209845997,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'portland',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -47.75406599432616,
#   'Lng': 135.11022952232224,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hilo',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 26.773621845962424,
#   'Lng': -142.28726979333314,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'cidreira',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -50.025293938360136,
#   'Lng': -27.578474628137116,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mataura',
#   'Cloudiness': None,
#   'Country': 'PF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -84.0020382644521,
#   'Lng': -165.6199309470368,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'palabuhanratu',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -19.732652813425474,
#   'Lng': 98.62927601519743,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'puerto ayora',
#   'Cloudiness': None,
#   'Country': 'EC',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -3.910750820093469,
#   'Lng': -111.41828630086452,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'amderma',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 74.59385696497037,
#   'Lng': 67.50286237935399,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'norman wells',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 61.48706854763569,
#   'Lng': -129.00603965586055,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ostrovnoy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 66.46587372297435,
#   'Lng': 40.54077172108768,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mingaora',
#   'Cloudiness': None,
#   'Country': 'PK',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 34.688208869391914,
#   'Lng': 72.55896691132665,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'catemaco',
#   'Cloudiness': None,
#   'Country': 'MX',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 19.754699843225268,
#   'Lng': -94.40549850042294,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nuuk',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 58.95922426845124,
#   'Lng': -56.612025409559024,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'lompoc',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 27.754518829412305,
#   'Lng': -126.24941207900147,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nome',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 64.93600257232114,
#   'Lng': -162.0617928612595,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'khor',
#   'Cloudiness': None,
#   'Country': 'QA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 26.140081585859974,
#   'Lng': 52.648712786039454,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saldanha',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -40.90190177797384,
#   'Lng': -2.228692776421127,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'burnie',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -45.50133972615609,
#   'Lng': 140.46551145868006,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'luanda',
#   'Cloudiness': None,
#   'Country': 'AO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -10.682822468250407,
#   'Lng': 8.9711100164198,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'benidorm',
#   'Cloudiness': None,
#   'Country': 'ES',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 38.039403099108455,
#   'Lng': -0.04029818661862805,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saint-francois',
#   'Cloudiness': None,
#   'Country': 'GP',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 18.156487870459273,
#   'Lng': -57.44846397255252,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'esperance',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -41.62054792572185,
#   'Lng': 127.12355577999125,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'qaanaaq',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 89.88630612221567,
#   'Lng': -71.91448485675889,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kavieng',
#   'Cloudiness': None,
#   'Country': 'PG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 12.226093169855474,
#   'Lng': 155.47119534215557,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saint anthony',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 53.54769037277967,
#   'Lng': -53.90416774642577,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'talnakh',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 74.82480689450077,
#   'Lng': 93.09680625318515,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vaitupu',
#   'Cloudiness': None,
#   'Country': 'WF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 6.894153738853504,
#   'Lng': -178.09125184594734,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'grand river south east',
#   'Cloudiness': None,
#   'Country': 'MU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -23.78530105942353,
#   'Lng': 76.27164087738669,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'pishchanka',
#   'Cloudiness': None,
#   'Country': 'UA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.139864016776414,
#   'Lng': 28.91482248797891,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'lydenburg',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -24.56400539174119,
#   'Lng': 30.415729050223888,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'san policarpo',
#   'Cloudiness': None,
#   'Country': 'PH',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 14.136226655144668,
#   'Lng': 128.46963302828732,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'clarence town',
#   'Cloudiness': None,
#   'Country': 'BS',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 21.921622042789423,
#   'Lng': -74.9962429002186,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'muli',
#   'Cloudiness': None,
#   'Country': 'MV',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 2.958917379052181,
#   'Lng': 77.40366713851216,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'khatanga',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 84.98005516562944,
#   'Lng': 105.15169112981079,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'lebu',
#   'Cloudiness': None,
#   'Country': 'CL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -35.52884903196127,
#   'Lng': -93.63688746971984,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mar del plata',
#   'Cloudiness': None,
#   'Country': 'AR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -60.179700871513965,
#   'Lng': -33.83915916374724,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'barentsburg',
#   'Cloudiness': None,
#   'Country': 'SJ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 80.0297819585191,
#   'Lng': 4.707445300285826,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'cody',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 43.70160855737734,
#   'Lng': -109.69818768540732,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'labutta',
#   'Cloudiness': None,
#   'Country': 'MM',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 15.66584726538811,
#   'Lng': 92.60278677662973,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sambava',
#   'Cloudiness': None,
#   'Country': 'MG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -12.575741582468254,
#   'Lng': 53.27847796418814,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'butterworth',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -32.194466351899614,
#   'Lng': 28.040496100091644,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kisangani',
#   'Cloudiness': None,
#   'Country': 'CD',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 1.4454934315032375,
#   'Lng': 25.13359098990867,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'winsum',
#   'Cloudiness': None,
#   'Country': 'NL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 54.57565657890413,
#   'Lng': 6.13039787494651,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'eyl',
#   'Cloudiness': None,
#   'Country': 'SO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 7.029695508324721,
#   'Lng': 51.36863272270415,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'thompson',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 63.0447134497073,
#   'Lng': -100.25479765763197,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bredasdorp',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -55.46154700970624,
#   'Lng': 19.429450808669912,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'dmitriyevka',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 53.218371850208655,
#   'Lng': 40.890443613705315,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'faanui',
#   'Cloudiness': None,
#   'Country': 'PF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -9.76740029444241,
#   'Lng': -156.19304840541335,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vaini',
#   'Cloudiness': None,
#   'Country': 'TO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -41.39515776644213,
#   'Lng': -173.96864332039297,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'havre-saint-pierre',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 49.452831340538836,
#   'Lng': -62.982595852316265,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tanabe',
#   'Cloudiness': None,
#   'Country': 'JP',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 33.96036255548077,
#   'Lng': 135.37493526816314,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mhlume',
#   'Cloudiness': None,
#   'Country': 'SZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -25.748497532113888,
#   'Lng': 31.587283605678635,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'longyearbyen',
#   'Cloudiness': None,
#   'Country': 'SJ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 74.76882800905415,
#   'Lng': 16.85068881523094,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ponta do sol',
#   'Cloudiness': None,
#   'Country': 'CV',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 21.79789644241987,
#   'Lng': -35.9023261142319,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'new norfolk',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -69.6381063006034,
#   'Lng': 124.9163161018655,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chhukha',
#   'Cloudiness': None,
#   'Country': 'BT',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 27.028851552324937,
#   'Lng': 89.53308384910918,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'anuradhapura',
#   'Cloudiness': None,
#   'Country': 'LK',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 8.443063878456144,
#   'Lng': 80.25316905933357,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'lota',
#   'Cloudiness': None,
#   'Country': 'CL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -37.16184828310445,
#   'Lng': -73.05633190507557,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tuktoyaktuk',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 78.5245366493919,
#   'Lng': -136.85300600156899,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'las vegas',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 35.54722306466236,
#   'Lng': -105.33145755629845,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'labuhan',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -14.899579297753732,
#   'Lng': 99.13686431244054,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ayagoz',
#   'Cloudiness': None,
#   'Country': 'KZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.98422088224973,
#   'Lng': 78.96002135751718,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kapaa',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 25.266985322481645,
#   'Lng': -168.8530500051078,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'darmanesti',
#   'Cloudiness': None,
#   'Country': 'RO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 46.4027008586574,
#   'Lng': 26.533357008778495,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'esna',
#   'Cloudiness': None,
#   'Country': 'EG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 23.94866225383936,
#   'Lng': 29.709208886476915,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'margate',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -39.48145735758464,
#   'Lng': 39.64859149733638,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'solnechnyy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 59.91486894020878,
#   'Lng': 140.3682256603168,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ust-kuyga',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 69.96062038425603,
#   'Lng': 134.23938925287598,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tasiilaq',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 73.59305081153877,
#   'Lng': -35.65285592690947,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'marathon',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.6266005400978,
#   'Lng': -86.20149299154276,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ilulissat',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 73.86037493391865,
#   'Lng': -44.524008611919726,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hermanus',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -76.38346560748701,
#   'Lng': -4.446778255527647,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sentyabrskiy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 27.66381686698051,
#   'Lng': 164.23398688223062,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'klaksvik',
#   'Cloudiness': None,
#   'Country': 'FO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 79.75713906154112,
#   'Lng': -5.090304859063139,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'benguela',
#   'Cloudiness': None,
#   'Country': 'AO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -12.420460111702255,
#   'Lng': 12.351467623347872,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mormugao',
#   'Cloudiness': None,
#   'Country': 'IN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 14.292001739408008,
#   'Lng': 71.93086043103642,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'umzimvubu',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -43.834327387950346,
#   'Lng': 39.32546593817494,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'verkhnyaya inta',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 66.0951999490969,
#   'Lng': 62.28886035293547,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'okhotsk',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 56.40785367698726,
#   'Lng': 144.60422245925145,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'leh',
#   'Cloudiness': None,
#   'Country': 'IN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 33.84866959564121,
#   'Lng': 80.12575253129074,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bereda',
#   'Cloudiness': None,
#   'Country': 'SO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 16.418158040704085,
#   'Lng': 49.15624278319754,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'khovu-aksy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 51.44172261095878,
#   'Lng': 93.94382045843912,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'belushya guba',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 84.12240902769895,
#   'Lng': 59.16880731847971,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'castelo branco',
#   'Cloudiness': None,
#   'Country': 'PT',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 39.8726234621883,
#   'Lng': -7.509139754357307,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'atar',
#   'Cloudiness': None,
#   'Country': 'MR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 23.69633480480924,
#   'Lng': -12.40366923563019,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nizhneyansk',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 88.83297566072841,
#   'Lng': 141.06388267612726,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'katangli',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 52.14383251167379,
#   'Lng': 146.53100132128526,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mount isa',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -22.549409606826273,
#   'Lng': 137.53507042088364,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'abonnema',
#   'Cloudiness': None,
#   'Country': 'NG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 2.8410808644249386,
#   'Lng': 5.761228436081495,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tiksi',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 85.65722777599129,
#   'Lng': 131.16858663270432,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nanortalik',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 60.627737429301135,
#   'Lng': -45.26020500264204,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'roznov',
#   'Cloudiness': None,
#   'Country': 'CZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 49.42728174235913,
#   'Lng': 18.196665185336116,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ancud',
#   'Cloudiness': None,
#   'Country': 'CL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -41.66758592858965,
#   'Lng': -77.17052651172278,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'khani',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 58.205382683017376,
#   'Lng': 122.26001507211873,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sindor',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 62.38723856670231,
#   'Lng': 52.51270333632624,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'airai',
#   'Cloudiness': None,
#   'Country': 'PW',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 16.59935910380547,
#   'Lng': 141.62031317392075,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chunskiy',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 56.19606231937004,
#   'Lng': 100.24543728554767,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hasaki',
#   'Cloudiness': None,
#   'Country': 'JP',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 24.86748513445717,
#   'Lng': 152.959998955424,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mouzakion',
#   'Cloudiness': None,
#   'Country': 'GR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 37.21501929863841,
#   'Lng': 20.043714434742697,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tuatapere',
#   'Cloudiness': None,
#   'Country': 'NZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -47.38019216699077,
#   'Lng': 160.32978391537154,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chicama',
#   'Cloudiness': None,
#   'Country': 'PE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -11.834730237118265,
#   'Lng': -87.16365555522694,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'hay river',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 65.09690978083964,
#   'Lng': -119.79586827764669,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'merritt island',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 29.57161341670117,
#   'Lng': -78.86271110645382,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'victoria',
#   'Cloudiness': None,
#   'Country': 'SC',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -8.4718913435199,
#   'Lng': 53.39843245993225,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tupiza',
#   'Cloudiness': None,
#   'Country': 'BO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -21.217741406501403,
#   'Lng': -65.9365942631623,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'nalut',
#   'Cloudiness': None,
#   'Country': 'LY',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 29.778357152192,
#   'Lng': 8.341643972393484,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kavaratti',
#   'Cloudiness': None,
#   'Country': 'IN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 12.68359520969257,
#   'Lng': 69.94524343922316,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kahului',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 34.76545623621374,
#   'Lng': -145.91093382275122,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'terrace bay',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 47.79400452651268,
#   'Lng': -86.96403228598686,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'khandyga',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 64.58837737594459,
#   'Lng': 138.02498488348851,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bairiki',
#   'Cloudiness': None,
#   'Country': 'KI',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.6797151224277513,
#   'Lng': 168.9923679173791,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'moiyabana',
#   'Cloudiness': None,
#   'Country': 'BW',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -22.385180066012524,
#   'Lng': 26.373363843098133,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'haines junction',
#   'Cloudiness': None,
#   'Country': 'CA',
#   'Date': None,
#   'Humidity': None,
# ...
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kawalu',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -8.835346293414005,
#   'Lng': 108.15292543555319,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'guapi',
#   'Cloudiness': None,
#   'Country': 'CO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 2.6063888596811466,
#   'Lng': -77.94045407445009,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'neuquen',
#   'Cloudiness': None,
#   'Country': 'AR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -37.0887624371463,
#   'Lng': -68.7286191996006,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'balaipungut',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 1.3344572046708834,
#   'Lng': 100.56062696999743,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chumikan',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 55.899467662887304,
#   'Lng': 135.26114495913038,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'siderno',
#   'Cloudiness': None,
#   'Country': 'IT',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 36.975352049766386,
#   'Lng': 17.615297794512372,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mogadishu',
#   'Cloudiness': None,
#   'Country': 'SO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.9956626926631884,
#   'Lng': 48.376527355408,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vanimo',
#   'Cloudiness': None,
#   'Country': 'PG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -3.9152265814611837,
#   'Lng': 140.68558588394507,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bonfim',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.19573404724582133,
#   'Lng': -59.126294203421125,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'benemerito de las americas',
#   'Cloudiness': None,
#   'Country': 'MX',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 16.700229683841073,
#   'Lng': -90.51396068990444,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'krasnoyarsk-45',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 56.10516601398987,
#   'Lng': 94.62165976705592,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'biak',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 1.7034920012148547,
#   'Lng': 135.65249520840786,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'galesong',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -5.9034143776706145,
#   'Lng': 119.07113276172237,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chancay',
#   'Cloudiness': None,
#   'Country': 'PE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -11.891302936678684,
#   'Lng': -78.12361660240978,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vardo',
#   'Cloudiness': None,
#   'Country': 'NO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 79.64808519640317,
#   'Lng': 36.123798632503394,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tuggurt',
#   'Cloudiness': None,
#   'Country': 'DZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 34.09981431625694,
#   'Lng': 4.586117154509196,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'jalu',
#   'Cloudiness': None,
#   'Country': 'LY',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 27.614798184447224,
#   'Lng': 22.49407386092159,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'arawa',
#   'Cloudiness': None,
#   'Country': 'PG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -3.6066082103437935,
#   'Lng': 155.19524933764268,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'paita',
#   'Cloudiness': None,
#   'Country': 'PE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -6.179648496885463,
#   'Lng': -83.40100460867434,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ceyhan',
#   'Cloudiness': None,
#   'Country': 'TR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 37.12077554128405,
#   'Lng': 35.84739162837647,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'beitbridge',
#   'Cloudiness': None,
#   'Country': 'ZW',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -21.78456624037608,
#   'Lng': 29.543514976138596,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vikhorevka',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 57.21648376650634,
#   'Lng': 100.38981878830452,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'san quintin',
#   'Cloudiness': None,
#   'Country': 'MX',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 30.656277069823844,
#   'Lng': -115.43563649049747,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'beidao',
#   'Cloudiness': None,
#   'Country': 'CN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 33.85467238431349,
#   'Lng': 105.72768552073626,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'humaita',
#   'Cloudiness': None,
#   'Country': 'PY',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -26.425115620135998,
#   'Lng': -59.220808917421365,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'qaqortoq',
#   'Cloudiness': None,
#   'Country': 'GL',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 62.93666702391741,
#   'Lng': -44.43168295497591,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'alofi',
#   'Cloudiness': None,
#   'Country': 'NU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -21.364496605516123,
#   'Lng': -170.1129538786361,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mantua',
#   'Cloudiness': None,
#   'Country': 'CU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 21.877778755622742,
#   'Lng': -84.63209999754329,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vicar',
#   'Cloudiness': None,
#   'Country': 'ES',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 37.17900471133886,
#   'Lng': -2.555408259053081,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'danville',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 40.2021773544748,
#   'Lng': -87.39499143733734,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'teya',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 61.00186043857312,
#   'Lng': 91.23645943652491,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'flinders',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -35.996763297056944,
#   'Lng': 130.8232290030324,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'saint-pierre',
#   'Cloudiness': None,
#   'Country': 'PM',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 40.12234080665988,
#   'Lng': -54.928898318504196,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vredendal',
#   'Cloudiness': None,
#   'Country': 'ZA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -31.328495665923583,
#   'Lng': 17.187140082041452,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'mao',
#   'Cloudiness': None,
#   'Country': 'TD',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 16.080320844040187,
#   'Lng': 15.453135812102005,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'oistins',
#   'Cloudiness': None,
#   'Country': 'BB',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 11.711567770062686,
#   'Lng': -57.35264830501022,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'avera',
#   'Cloudiness': None,
#   'Country': 'PF',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -25.66664448421166,
#   'Lng': -155.63086830029528,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'vega de alatorre',
#   'Cloudiness': None,
#   'Country': 'MX',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 22.339932778079458,
#   'Lng': -93.98775540215433,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'byron bay',
#   'Cloudiness': None,
#   'Country': 'AU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -27.8107641629176,
#   'Lng': 157.5560817176363,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'rincon',
#   'Cloudiness': None,
#   'Country': 'AN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 12.566925530575446,
#   'Lng': -68.51464723433078,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bath',
#   'Cloudiness': None,
#   'Country': 'US',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 43.91998936825317,
#   'Lng': -69.79437151745844,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'pareora',
#   'Cloudiness': None,
#   'Country': 'NZ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -44.98560560604927,
#   'Lng': 171.74421637391896,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sinjar',
#   'Cloudiness': None,
#   'Country': 'IQ',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 35.67239549551191,
#   'Lng': 41.41335349046969,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'finschhafen',
#   'Cloudiness': None,
#   'Country': 'PG',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -5.319157985058212,
#   'Lng': 147.56136745182857,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'perleberg',
#   'Cloudiness': None,
#   'Country': 'DE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 52.98383665154586,
#   'Lng': 12.030202762893623,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'viligili',
#   'Cloudiness': None,
#   'Country': 'MV',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.5422399955788251,
#   'Lng': 74.0627228353616,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'salekhard',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 65.2970719590837,
#   'Lng': 66.24827809928186,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'partizanske',
#   'Cloudiness': None,
#   'Country': 'SK',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.63038006966221,
#   'Lng': 18.355319756685844,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kletskaya',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 49.59428765171393,
#   'Lng': 43.12645250023468,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'westpunt',
#   'Cloudiness': None,
#   'Country': 'AN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 14.70196402484136,
#   'Lng': -69.11104786948802,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'tomohon',
#   'Cloudiness': None,
#   'Country': 'ID',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 1.113888036282745,
#   'Lng': 124.66060484078548,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'jiddah',
#   'Cloudiness': None,
#   'Country': 'SA',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 21.604541763868696,
#   'Lng': 39.41518940440753,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'turinsk',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 58.55626514175805,
#   'Lng': 63.051469146465394,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'beian',
#   'Cloudiness': None,
#   'Country': 'CN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 48.022681840835645,
#   'Lng': 127.16646661393662,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'niamey',
#   'Cloudiness': None,
#   'Country': 'NE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 13.606881451635644,
#   'Lng': 1.9828185549000636,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'abu dhabi',
#   'Cloudiness': None,
#   'Country': 'AE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 23.499117475067877,
#   'Lng': 54.97552123993981,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'thinadhoo',
#   'Cloudiness': None,
#   'Country': 'MV',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -0.0013781026930246298,
#   'Lng': 72.9128130818981,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'ligayan',
#   'Cloudiness': None,
#   'Country': 'PH',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 3.522891289408008,
#   'Lng': 119.52283652537704,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'chifeng',
#   'Cloudiness': None,
#   'Country': 'CN',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 43.12375395950042,
#   'Lng': 119.59051267965299,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'srednekolymsk',
#   'Cloudiness': None,
#   'Country': 'RU',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 67.63461535375191,
#   'Lng': 153.00099989685543,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'bolungarvik',
#   'Cloudiness': None,
#   'Country': 'IS',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 67.90646392223016,
#   'Lng': -28.671043568309983,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'sayyan',
#   'Cloudiness': None,
#   'Country': 'YE',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 16.015540613383408,
#   'Lng': 46.75249529743624,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'kasama',
#   'Cloudiness': None,
#   'Country': 'ZM',
#   'Date': None,
#   'Humidity': None,
#   'Lat': -9.826568435033167,
#   'Lng': 30.88888844897781,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'beruwala',
#   'Cloudiness': None,
#   'Country': 'LK',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 5.690721041619057,
#   'Lng': 78.69627989122773,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'barcelos',
#   'Cloudiness': None,
#   'Country': 'BR',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 0.16348778779945405,
#   'Lng': -61.95345183874717,
#   'Max Temp': None,
#   'Wind Speed': None},
#  {'Is_Fetch_Ok': False,
#   'City_ID': None,
#   'City': 'roald',
#   'Cloudiness': None,
#   'Country': 'NO',
#   'Date': None,
#   'Humidity': None,
#   'Lat': 74.31494184223905,
#   'Lng': 0.5574677448774707,
#   'Max Temp': None,
#   'Wind Speed': None}]

# %%
#Function to print running log of city number and name.  Will print city name if the city contains 500+ people, otherwise
#the city name will not be printed

def print_city_log(status_code, 
                   city_name          = None, 
                   rec_set            = None, 
                   fetched_rec_counter= None):
    
    if(status_code == 200):
        print(f"Processing Record {counter} | {city_name}")
    else:
        print("City not found. Skipping...")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build query URL
  
#out_cols = ["City_ID","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]

fetched_rec_counter = 0
record_set = 1

for i in range(len(weather_container)):
    
    weather_hash = weather_container[i]
    city_name    = weather_hash[city]
    weather_query_url = weather_url + "appid=" + weather_api_key + "&q=" + city_name

    print(i)
    break
    
    if (i + 1) % 60 != 0:
        
        weather_response  = requests.get(weather_query_url)
        status_code       = weather_response.status_code

        if(status_code == 200):

            weather_json = weather_response.json()
            fetched_rec_counter += 1
            weather_hash[is_fetch_ok] = True
            weather_hash[city_id]     = counter
            weather_hash[date]        = weather_json["dt"]
            weather_hash[max_temp]    = weather_json["main"]["temp_max"]
            weather_hash[humidity]    = weather_json["main"]["humidity"]      
            weather_hash[wind_speed]  = weather_json["wind"]["speed"]
            weather_hash[cloudiness]  = weather_json["clouds"]["all"]

            print_city_log(status_code,
                           city_name,
                           record_set,
                           fetched_rec_counter)

        else:
            print_city_log(status_code) 
    
    else:
        record_set += 1
        time.sleep(60)
# Out:
# 0

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put data into DataFrame
raw_results = pd.DataFrame(weather_container)
fetched_results = raw_results.loc[raw_results["Is_Fetch_Ok"] == True][[city_id,
                                                                       city,
                                                                       cloudiness,
                                                                       country,
                                                                       date,
                                                                       humidity,
                                                                       lat,
                                                                       lng,
                                                                       max_temp,
                                                                       wind_speed]].set_index(city_id)

#Export the DataFrame to CSV
fetched_results.to_csv(output_data_file,header=True,mode='w',index=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

humidity_over_100_pct = fetched_results.loc[fetched_results[humidity] > 0].reset_index()[[city_id,country,city,humidity]] \
                                                                            .set_index(city_id)
                                                                            
humidity_over_100_pct.head(300)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
